# %%
import pandas as pd
import random
import numpy as np

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 573

# %%
# Import the requests library.
import requests

#Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1402541877e53dfe4da01a70b35d9280

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# try:
    # Do something
#except:
    # print("An exception occurred")
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 1 | barguzin
# Processing Record 3 of Set 1 | erdenet
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | lebu
# Processing Record 6 of Set 1 | cockburn town
# Processing Record 7 of Set 1 | longyearbyen
# Processing Record 8 of Set 1 | pravia
# Processing Record 9 of Set 1 | sao joao da barra
# Processing Record 10 of Set 1 | paamiut
# Processing Record 11 of Set 1 | kodiak
# Processing Record 12 of Set 1 | saint-philippe
# Processing Record 13 of Set 1 | ilulissat
# Processing Record 14 of Set 1 | road town
# Processing Record 15 of Set 1 | bredasdorp
# Processing Record 16 of Set 1 | avarua
# Processing Record 17 of Set 1 | hermanus
# Processing Record 18 of Set 1 | shimoda
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | vao
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | kidal
# Processing Record 23 of Set 1 | pevek
# Processing Record 24 of Set 1 | iwata
# Processing Record 25 of Set 1 | cassia
# Processing Record 26 of Set 1 | comodoro rivadavia
# Processing Record 27 of Set 1 | provideniya
# Processing Record 28 of Set 1 | japura
# Processing Record 29 of Set 1 | baoqing
# Processing Record 30 of Set 1 | mar del plata
# Processing Record 31 of Set 1 | ushuaia
# Processing Record 32 of Set 1 | butaritari
# Processing Record 33 of Set 1 | taoudenni
# Processing Record 34 of Set 1 | samalaeulu
# City not found. Skipping...
# Processing Record 35 of Set 1 | bluff
# Processing Record 36 of Set 1 | tuktoyaktuk
# Processing Record 37 of Set 1 | flinders
# Processing Record 38 of Set 1 | mabaruma
# Processing Record 39 of Set 1 | qaanaaq
# Processing Record 40 of Set 1 | qaqortoq
# Processing Record 41 of Set 1 | castro
# Processing Record 42 of Set 1 | port alfred
# Processing Record 43 of Set 1 | poltavka
# Processing Record 44 of Set 1 | cidreira
# Processing Record 45 of Set 1 | ugoofaaru
# Processing Record 46 of Set 1 | whitstable
# Processing Record 47 of Set 1 | ossora
# Processing Record 48 of Set 1 | fortuna
# Processing Record 49 of Set 1 | lata
# Processing Record 50 of Set 1 | bria
# Processing Record 1 of Set 2 | isangel
# Processing Record 2 of Set 2 | simao
# Processing Record 3 of Set 2 | seydi
# Processing Record 4 of Set 2 | vanderhoof
# Processing Record 5 of Set 2 | finale ligure
# Processing Record 6 of Set 2 | cape town
# Processing Record 7 of Set 2 | dunedin
# Processing Record 8 of Set 2 | constitucion
# Processing Record 9 of Set 2 | tazovskiy
# Processing Record 10 of Set 2 | biak
# Processing Record 11 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 2 | micheweni
# Processing Record 13 of Set 2 | puerto escondido
# Processing Record 14 of Set 2 | punta arenas
# Processing Record 15 of Set 2 | ribeira grande
# Processing Record 16 of Set 2 | bengkulu
# Processing Record 17 of Set 2 | san cristobal
# Processing Record 18 of Set 2 | bonfim
# Processing Record 19 of Set 2 | bandarbeyla
# Processing Record 20 of Set 2 | saskylakh
# Processing Record 21 of Set 2 | phek
# Processing Record 22 of Set 2 | roald
# Processing Record 23 of Set 2 | broome
# Processing Record 24 of Set 2 | toamasina
# Processing Record 25 of Set 2 | torquay
# Processing Record 26 of Set 2 | atuona
# Processing Record 27 of Set 2 | chicama
# Processing Record 28 of Set 2 | jawa
# Processing Record 29 of Set 2 | port hardy
# Processing Record 30 of Set 2 | clyde river
# Processing Record 31 of Set 2 | lakshmipur
# Processing Record 32 of Set 2 | guayaramerin
# Processing Record 33 of Set 2 | hilo
# Processing Record 34 of Set 2 | albany
# Processing Record 35 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 2 | nikolskoye
# Processing Record 37 of Set 2 | tommot
# Processing Record 38 of Set 2 | katsuura
# Processing Record 39 of Set 2 | jamestown
# Processing Record 40 of Set 2 | lagoa
# Processing Record 41 of Set 2 | douglas
# Processing Record 42 of Set 2 | saquena
# Processing Record 43 of Set 2 | yellowknife
# Processing Record 44 of Set 2 | umea
# Processing Record 45 of Set 2 | tiznit
# Processing Record 46 of Set 2 | chokurdakh
# Processing Record 47 of Set 2 | barrow
# Processing Record 48 of Set 2 | puerto ayora
# Processing Record 49 of Set 2 | yulara
# Processing Record 50 of Set 2 | srednekolymsk
# Processing Record 1 of Set 3 | chartres
# Processing Record 2 of Set 3 | la rioja
# Processing Record 3 of Set 3 | ewa beach
# Processing Record 4 of Set 3 | lompoc
# Processing Record 5 of Set 3 | chuy
# Processing Record 6 of Set 3 | georgetown
# Processing Record 7 of Set 3 | victoria
# Processing Record 8 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 3 | plaster rock
# Processing Record 10 of Set 3 | salalah
# Processing Record 11 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 3 | bandhi
# Processing Record 13 of Set 3 | port-gentil
# Processing Record 14 of Set 3 | jaque
# Processing Record 15 of Set 3 | ankang
# Processing Record 16 of Set 3 | la ronge
# Processing Record 17 of Set 3 | hithadhoo
# Processing Record 18 of Set 3 | ballina
# Processing Record 19 of Set 3 | andevoranto
# City not found. Skipping...
# Processing Record 20 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 3 | podporozhye
# Processing Record 22 of Set 3 | waddan
# Processing Record 23 of Set 3 | carnarvon
# Processing Record 24 of Set 3 | takapau
# Processing Record 25 of Set 3 | bloemfontein
# Processing Record 26 of Set 3 | izhmorskiy
# Processing Record 27 of Set 3 | norman wells
# Processing Record 28 of Set 3 | yumen
# Processing Record 29 of Set 3 | cap malheureux
# Processing Record 30 of Set 3 | abancay
# Processing Record 31 of Set 3 | arraial do cabo
# Processing Record 32 of Set 3 | dhidhdhoo
# Processing Record 33 of Set 3 | karratha
# Processing Record 34 of Set 3 | kaitangata
# Processing Record 35 of Set 3 | upernavik
# Processing Record 36 of Set 3 | vila franca do campo
# Processing Record 37 of Set 3 | tsaratanana
# Processing Record 38 of Set 3 | saint-pierre
# Processing Record 39 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 3 | vaini
# Processing Record 41 of Set 3 | san luis
# Processing Record 42 of Set 3 | tuatapere
# Processing Record 43 of Set 3 | kruisfontein
# Processing Record 44 of Set 3 | huilong
# Processing Record 45 of Set 3 | lithgow
# Processing Record 46 of Set 3 | dingle
# Processing Record 47 of Set 3 | muriti
# Processing Record 48 of Set 3 | hanzhong
# Processing Record 49 of Set 3 | east london
# Processing Record 50 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 4 | hasaki
# Processing Record 2 of Set 4 | isla vista
# Processing Record 3 of Set 4 | sola
# Processing Record 4 of Set 4 | esperance
# Processing Record 5 of Set 4 | hobart
# Processing Record 6 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 4 | narsaq
# Processing Record 8 of Set 4 | santa rita
# Processing Record 9 of Set 4 | lasa
# Processing Record 10 of Set 4 | atar
# Processing Record 11 of Set 4 | waipawa
# Processing Record 12 of Set 4 | grand gaube
# Processing Record 13 of Set 4 | high level
# Processing Record 14 of Set 4 | kovdor
# Processing Record 15 of Set 4 | songkhla
# Processing Record 16 of Set 4 | hellvik
# Processing Record 17 of Set 4 | cullman
# Processing Record 18 of Set 4 | qingyuan
# Processing Record 19 of Set 4 | port elizabeth
# Processing Record 20 of Set 4 | mahebourg
# Processing Record 21 of Set 4 | tasiilaq
# Processing Record 22 of Set 4 | uyuni
# Processing Record 23 of Set 4 | mattawa
# Processing Record 24 of Set 4 | canmore
# Processing Record 25 of Set 4 | vanimo
# Processing Record 26 of Set 4 | oranjemund
# Processing Record 27 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 28 of Set 4 | kapaa
# Processing Record 29 of Set 4 | cabo san lucas
# Processing Record 30 of Set 4 | yebaishou
# Processing Record 31 of Set 4 | cabedelo
# Processing Record 32 of Set 4 | leshukonskoye
# Processing Record 33 of Set 4 | jurado
# Processing Record 34 of Set 4 | vestmanna
# Processing Record 35 of Set 4 | hamilton
# Processing Record 36 of Set 4 | ruffano
# Processing Record 37 of Set 4 | marfino
# Processing Record 38 of Set 4 | shache
# Processing Record 39 of Set 4 | karkaralinsk
# City not found. Skipping...
# Processing Record 40 of Set 4 | haines junction
# Processing Record 41 of Set 4 | owando
# Processing Record 42 of Set 4 | namatanai
# Processing Record 43 of Set 4 | pandan
# Processing Record 44 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 4 | amguri
# Processing Record 46 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 4 | ponta do sol
# Processing Record 48 of Set 4 | aklavik
# Processing Record 49 of Set 4 | winnetka
# Processing Record 50 of Set 4 | tiruvottiyur
# City not found. Skipping...
# Processing Record 1 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 2 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 3 of Set 5 | izhma
# Processing Record 4 of Set 5 | tessalit
# Processing Record 5 of Set 5 | channel-port aux basques
# Processing Record 6 of Set 5 | narasannapeta
# Processing Record 7 of Set 5 | elk plain
# Processing Record 8 of Set 5 | papara
# Processing Record 9 of Set 5 | monrovia
# Processing Record 10 of Set 5 | tungkang
# City not found. Skipping...
# Processing Record 11 of Set 5 | iqaluit
# Processing Record 12 of Set 5 | tarbagatay
# Processing Record 13 of Set 5 | bethel
# Processing Record 14 of Set 5 | bonavista
# Processing Record 15 of Set 5 | los llanos de aridane
# Processing Record 16 of Set 5 | temaraia
# City not found. Skipping...
# Processing Record 17 of Set 5 | yamasaki
# Processing Record 18 of Set 5 | lixourion
# Processing Record 19 of Set 5 | henties bay
# Processing Record 20 of Set 5 | alyangula
# Processing Record 21 of Set 5 | faya
# Processing Record 22 of Set 5 | te anau
# Processing Record 23 of Set 5 | seoul
# Processing Record 24 of Set 5 | havelock
# Processing Record 25 of Set 5 | kavieng
# Processing Record 26 of Set 5 | marzuq
# Processing Record 27 of Set 5 | balimo
# City not found. Skipping...
# Processing Record 28 of Set 5 | ixtapa
# Processing Record 29 of Set 5 | qom
# Processing Record 30 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 5 | praia da vitoria
# Processing Record 32 of Set 5 | whitianga
# Processing Record 33 of Set 5 | san quintin
# Processing Record 34 of Set 5 | laguna
# Processing Record 35 of Set 5 | kutum
# Processing Record 36 of Set 5 | pangnirtung
# Processing Record 37 of Set 5 | hami
# Processing Record 38 of Set 5 | wilmington
# Processing Record 39 of Set 5 | brae
# Processing Record 40 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 5 | yeppoon
# Processing Record 42 of Set 5 | ziarat
# Processing Record 43 of Set 5 | salmon arm
# Processing Record 44 of Set 5 | mana
# Processing Record 45 of Set 5 | khatanga
# Processing Record 46 of Set 5 | scottsboro
# Processing Record 47 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 5 | adrar
# Processing Record 49 of Set 5 | poum
# Processing Record 50 of Set 5 | cockburn harbour
# City not found. Skipping...
# Processing Record 1 of Set 6 | guerrero negro
# Processing Record 2 of Set 6 | faanui
# Processing Record 3 of Set 6 | dikson
# Processing Record 4 of Set 6 | alofi
# Processing Record 5 of Set 6 | abay
# Processing Record 6 of Set 6 | gizo
# Processing Record 7 of Set 6 | thompson
# Processing Record 8 of Set 6 | zhigansk
# Processing Record 9 of Set 6 | darhan
# Processing Record 10 of Set 6 | labuhan
# Processing Record 11 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 6 | souillac
# Processing Record 13 of Set 6 | sheltozero
# Processing Record 14 of Set 6 | kieta
# Processing Record 15 of Set 6 | emerald
# Processing Record 16 of Set 6 | touros
# Processing Record 17 of Set 6 | tiruttani
# Processing Record 18 of Set 6 | borovoy
# Processing Record 19 of Set 6 | padang
# Processing Record 20 of Set 6 | nokaneng
# Processing Record 21 of Set 6 | winnemucca
# Processing Record 22 of Set 6 | batagay-alyta
# Processing Record 23 of Set 6 | shingu
# Processing Record 24 of Set 6 | torbay
# Processing Record 25 of Set 6 | zaysan
# Processing Record 26 of Set 6 | port augusta
# Processing Record 27 of Set 6 | leningradskiy
# Processing Record 28 of Set 6 | sept-iles
# Processing Record 29 of Set 6 | tura
# Processing Record 30 of Set 6 | talnakh
# Processing Record 31 of Set 6 | chimore
# Processing Record 32 of Set 6 | bathsheba
# Processing Record 33 of Set 6 | smithers
# Processing Record 34 of Set 6 | salihorsk
# Processing Record 35 of Set 6 | bolshaya chernigovka
# City not found. Skipping...
# Processing Record 36 of Set 6 | nanortalik
# Processing Record 37 of Set 6 | pallasovka
# Processing Record 38 of Set 6 | lazarev
# Processing Record 39 of Set 6 | coihaique
# Processing Record 40 of Set 6 | vilhena
# Processing Record 41 of Set 6 | nuuk
# Processing Record 42 of Set 6 | cordoba
# Processing Record 43 of Set 6 | willowmore
# Processing Record 44 of Set 6 | umm lajj
# Processing Record 45 of Set 6 | yate
# Processing Record 46 of Set 6 | moose factory
# Processing Record 47 of Set 6 | sorland
# Processing Record 48 of Set 6 | lesnyye polyany
# Processing Record 49 of Set 6 | monkey hill
# Processing Record 50 of Set 6 | san andres
# Processing Record 1 of Set 7 | sobolevo
# Processing Record 2 of Set 7 | chapais
# Processing Record 3 of Set 7 | suzun
# Processing Record 4 of Set 7 | ginda
# Processing Record 5 of Set 7 | ponta delgada
# Processing Record 6 of Set 7 | luderitz
# Processing Record 7 of Set 7 | kaeo
# Processing Record 8 of Set 7 | cherskiy
# Processing Record 9 of Set 7 | vila do maio
# Processing Record 10 of Set 7 | bousso
# Processing Record 11 of Set 7 | alice springs
# Processing Record 12 of Set 7 | walvis bay
# Processing Record 13 of Set 7 | muros
# Processing Record 14 of Set 7 | santa marta
# Processing Record 15 of Set 7 | kralendijk
# Processing Record 16 of Set 7 | sioux lookout
# Processing Record 17 of Set 7 | qasigiannguit
# Processing Record 18 of Set 7 | sarangani
# Processing Record 19 of Set 7 | geraldton
# Processing Record 20 of Set 7 | guozhen
# Processing Record 21 of Set 7 | nelson bay
# Processing Record 22 of Set 7 | ranfurly
# Processing Record 23 of Set 7 | eyemouth
# Processing Record 24 of Set 7 | mumbwa
# Processing Record 25 of Set 7 | half moon bay
# Processing Record 26 of Set 7 | new norfolk
# Processing Record 27 of Set 7 | ancud
# Processing Record 28 of Set 7 | dera bugti
# Processing Record 29 of Set 7 | mercedes
# Processing Record 30 of Set 7 | tatawin
# Processing Record 31 of Set 7 | voh
# Processing Record 32 of Set 7 | san jeronimo
# Processing Record 33 of Set 7 | goderich
# Processing Record 34 of Set 7 | port macquarie
# Processing Record 35 of Set 7 | omsukchan
# Processing Record 36 of Set 7 | ankazoabo
# Processing Record 37 of Set 7 | darlowo
# Processing Record 38 of Set 7 | cayenne
# Processing Record 39 of Set 7 | toyooka
# Processing Record 40 of Set 7 | port lincoln
# Processing Record 41 of Set 7 | vagur
# Processing Record 42 of Set 7 | denham springs
# Processing Record 43 of Set 7 | victoria point
# Processing Record 44 of Set 7 | kasongo-lunda
# Processing Record 45 of Set 7 | afmadu
# City not found. Skipping...
# Processing Record 46 of Set 7 | cedar city
# Processing Record 47 of Set 7 | fuerte olimpo
# Processing Record 48 of Set 7 | nalut
# Processing Record 49 of Set 7 | sawakin
# Processing Record 50 of Set 7 | okhotsk
# Processing Record 1 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 2 of Set 8 | egvekinot
# Processing Record 3 of Set 8 | tiksi
# Processing Record 4 of Set 8 | avera
# Processing Record 5 of Set 8 | wucheng
# Processing Record 6 of Set 8 | hambantota
# Processing Record 7 of Set 8 | san jose
# Processing Record 8 of Set 8 | martapura
# Processing Record 9 of Set 8 | bahia blanca
# Processing Record 10 of Set 8 | altar
# Processing Record 11 of Set 8 | along
# Processing Record 12 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 13 of Set 8 | ulladulla
# Processing Record 14 of Set 8 | lodwar
# Processing Record 15 of Set 8 | alekseyevsk
# Processing Record 16 of Set 8 | dalvik
# Processing Record 17 of Set 8 | kavaratti
# Processing Record 18 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 8 | williston
# Processing Record 20 of Set 8 | hay river
# Processing Record 21 of Set 8 | pisco
# Processing Record 22 of Set 8 | karakol
# Processing Record 23 of Set 8 | ahipara
# Processing Record 24 of Set 8 | hualmay
# Processing Record 25 of Set 8 | zhob
# Processing Record 26 of Set 8 | acapulco
# Processing Record 27 of Set 8 | petatlan
# Processing Record 28 of Set 8 | sinnamary
# Processing Record 29 of Set 8 | havre-saint-pierre
# Processing Record 30 of Set 8 | natal
# Processing Record 31 of Set 8 | paramonga
# Processing Record 32 of Set 8 | san rafael
# Processing Record 33 of Set 8 | riyadh
# Processing Record 34 of Set 8 | lavrentiya
# Processing Record 35 of Set 8 | northam
# Processing Record 36 of Set 8 | bela
# Processing Record 37 of Set 8 | maraba
# Processing Record 38 of Set 8 | yakuplu
# Processing Record 39 of Set 8 | energetik
# Processing Record 40 of Set 8 | bantry
# Processing Record 41 of Set 8 | matara
# Processing Record 42 of Set 8 | peniche
# Processing Record 43 of Set 8 | phan rang
# City not found. Skipping...
# Processing Record 44 of Set 8 | ayame
# Processing Record 45 of Set 8 | huazolotitlan
# City not found. Skipping...
# Processing Record 46 of Set 8 | tambun
# Processing Record 47 of Set 8 | boa vista
# Processing Record 48 of Set 8 | ca mau
# Processing Record 49 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 9 | ostrovnoy
# Processing Record 2 of Set 9 | caravelas
# Processing Record 3 of Set 9 | pacifica
# Processing Record 4 of Set 9 | narsimhapur
# Processing Record 5 of Set 9 | saint-augustin
# Processing Record 6 of Set 9 | oskaloosa
# Processing Record 7 of Set 9 | sambava
# Processing Record 8 of Set 9 | necochea
# Processing Record 9 of Set 9 | sechura
# Processing Record 10 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 11 of Set 9 | anadyr
# Processing Record 12 of Set 9 | klaksvik
# Processing Record 13 of Set 9 | pahrump
# Processing Record 14 of Set 9 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 15 of Set 9 | gat
# Processing Record 16 of Set 9 | beloha
# Processing Record 17 of Set 9 | coquimbo
# Processing Record 18 of Set 9 | plettenberg bay
# Processing Record 19 of Set 9 | boguchany
# Processing Record 20 of Set 9 | pine castle
# Processing Record 21 of Set 9 | rocha
# Processing Record 22 of Set 9 | kahului
# Processing Record 23 of Set 9 | port blair
# Processing Record 24 of Set 9 | palauig
# Processing Record 25 of Set 9 | kadykchan
# City not found. Skipping...
# Processing Record 26 of Set 9 | stornoway
# Processing Record 27 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 9 | miri
# Processing Record 29 of Set 9 | carlyle
# Processing Record 30 of Set 9 | begusarai
# Processing Record 31 of Set 9 | naron
# Processing Record 32 of Set 9 | lorengau
# Processing Record 33 of Set 9 | menongue
# Processing Record 34 of Set 9 | myitkyina
# Processing Record 35 of Set 9 | yerbogachen
# Processing Record 36 of Set 9 | makarska
# Processing Record 37 of Set 9 | ninotsminda
# Processing Record 38 of Set 9 | port hedland
# Processing Record 39 of Set 9 | nioaque
# Processing Record 40 of Set 9 | kununurra
# Processing Record 41 of Set 9 | beringovskiy
# Processing Record 42 of Set 9 | rusape
# Processing Record 43 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 44 of Set 9 | tautira
# Processing Record 45 of Set 9 | murgab
# Processing Record 46 of Set 9 | batemans bay
# Processing Record 47 of Set 9 | porosozero
# Processing Record 48 of Set 9 | soyo
# Processing Record 49 of Set 9 | aksu
# Processing Record 50 of Set 9 | mutsamudu
# City not found. Skipping...
# Processing Record 1 of Set 10 | severnyy
# Processing Record 2 of Set 10 | san-pedro
# Processing Record 3 of Set 10 | nsoko
# Processing Record 4 of Set 10 | lubao
# Processing Record 5 of Set 10 | kisangani
# Processing Record 6 of Set 10 | hastings
# Processing Record 7 of Set 10 | sao filipe
# Processing Record 8 of Set 10 | rio gallegos
# Processing Record 9 of Set 10 | nikolsk
# Processing Record 10 of Set 10 | najran
# Processing Record 11 of Set 10 | berlevag
# Processing Record 12 of Set 10 | margate
# Processing Record 13 of Set 10 | ozernovskiy
# Processing Record 14 of Set 10 | yar-sale
# Processing Record 15 of Set 10 | sulangan
# Processing Record 16 of Set 10 | sawtell
# Processing Record 17 of Set 10 | troitsko-pechorsk
# Processing Record 18 of Set 10 | saldanha
# Processing Record 19 of Set 10 | vieux-habitants
# Processing Record 20 of Set 10 | hofn
# Processing Record 21 of Set 10 | barinas
# Processing Record 22 of Set 10 | fort saint john
# City not found. Skipping...
# Processing Record 23 of Set 10 | saint george
# Processing Record 24 of Set 10 | mandera
# Processing Record 25 of Set 10 | boden
# Processing Record 26 of Set 10 | yarim
# Processing Record 27 of Set 10 | buraydah
# Processing Record 28 of Set 10 | vidalia
# Processing Record 29 of Set 10 | aguilas
# Processing Record 30 of Set 10 | carutapera
# Processing Record 31 of Set 10 | north bend
# Processing Record 32 of Set 10 | bilma
# Processing Record 33 of Set 10 | mogadishu
# Processing Record 34 of Set 10 | casper
# Processing Record 35 of Set 10 | basco
# Processing Record 36 of Set 10 | inuvik
# Processing Record 37 of Set 10 | salinopolis
# Processing Record 38 of Set 10 | sangar
# Processing Record 39 of Set 10 | valdivia
# Processing Record 40 of Set 10 | sosnovka
# Processing Record 41 of Set 10 | mayumba
# Processing Record 42 of Set 10 | podosinovets
# Processing Record 43 of Set 10 | esmeralda
# Processing Record 44 of Set 10 | sitka
# Processing Record 45 of Set 10 | kirakira
# Processing Record 46 of Set 10 | kholm-zhirkovskiy
# Processing Record 47 of Set 10 | graz
# Processing Record 48 of Set 10 | tubuala
# Processing Record 49 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 50 of Set 10 | satun
# Processing Record 1 of Set 11 | semey
# Processing Record 2 of Set 11 | preobrazheniye
# Processing Record 3 of Set 11 | aketi
# Processing Record 4 of Set 11 | urdzhar
# City not found. Skipping...
# Processing Record 5 of Set 11 | tomatlan
# Processing Record 6 of Set 11 | codrington
# Processing Record 7 of Set 11 | irbeyskoye
# Processing Record 8 of Set 11 | mayo
# Processing Record 9 of Set 11 | malatya
# Processing Record 10 of Set 11 | vila velha
# Processing Record 11 of Set 11 | lakatoro
# Processing Record 12 of Set 11 | yangjiang
# Processing Record 13 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 14 of Set 11 | talaya
# Processing Record 15 of Set 11 | palmer
# Processing Record 16 of Set 11 | zyryanka
# Processing Record 17 of Set 11 | harper
# Processing Record 18 of Set 11 | kouvola
# Processing Record 19 of Set 11 | saryshagan
# City not found. Skipping...
# Processing Record 20 of Set 11 | kiruna
# Processing Record 21 of Set 11 | chilca
# Processing Record 22 of Set 11 | zhanaozen
# Processing Record 23 of Set 11 | evensk
# Processing Record 24 of Set 11 | mbandaka
# Processing Record 25 of Set 11 | srivardhan
# Processing Record 26 of Set 11 | kandrian
# Processing Record 27 of Set 11 | manzhouli
# Processing Record 28 of Set 11 | garowe
# Processing Record 29 of Set 11 | asau
# Processing Record 30 of Set 11 | joshimath
# Processing Record 31 of Set 11 | lithakia
# Processing Record 32 of Set 11 | turan
# Processing Record 33 of Set 11 | tynda
# Processing Record 34 of Set 11 | xining
# Processing Record 35 of Set 11 | qarchi gak
# Processing Record 36 of Set 11 | mount pleasant
# Processing Record 37 of Set 11 | fort payne
# Processing Record 38 of Set 11 | fort nelson
# Processing Record 39 of Set 11 | sabha
# Processing Record 40 of Set 11 | shadrinsk
# Processing Record 41 of Set 11 | skibbereen
# Processing Record 42 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 43 of Set 11 | inverell
# Processing Record 44 of Set 11 | wageningen
# Processing Record 45 of Set 11 | pacific grove
# Processing Record 46 of Set 11 | yaan
# Processing Record 47 of Set 11 | jacareacanga
# Processing Record 48 of Set 11 | nouakchott
# Processing Record 49 of Set 11 | teya
# Processing Record 50 of Set 11 | sur
# Processing Record 1 of Set 12 | heiligenhafen
# Processing Record 2 of Set 12 | makakilo city
# Processing Record 3 of Set 12 | bereda
# Processing Record 4 of Set 12 | pryazha
# Processing Record 5 of Set 12 | nemuro
# Processing Record 6 of Set 12 | worland
# Processing Record 7 of Set 12 | meulaboh
# Processing Record 8 of Set 12 | labrea
# Processing Record 9 of Set 12 | vardo
# Processing Record 10 of Set 12 | barentu
# Processing Record 11 of Set 12 | narsipatnam
# Processing Record 12 of Set 12 | ekhabi
# Processing Record 13 of Set 12 | eureka
# Processing Record 14 of Set 12 | puerto armuelles
# Processing Record 15 of Set 12 | zaoyang
# Processing Record 16 of Set 12 | bambous virieux
# Processing Record 17 of Set 12 | coahuayana
# Processing Record 18 of Set 12 | the pas
# Processing Record 19 of Set 12 | yatou
# Processing Record 20 of Set 12 | haverfordwest
# Processing Record 21 of Set 12 | hailar
# Processing Record 22 of Set 12 | tenamaxtlan
# Processing Record 23 of Set 12 | santa maria
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 526

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data).drop(["Date"], axis=1)
city_data_df.head(10)
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Barguzin  53.6167  109.6167     36.75        54          93
# 1            Erdenet  49.0333  104.0833     35.89        35         100
# 2          Busselton -33.6500  115.3333     72.00        54           4
# 3               Lebu -37.6167  -73.6500     54.19        85           8
# 4      Cockburn Town  21.4612  -71.1419     73.62        63          28
# 5       Longyearbyen  78.2186   15.6401     10.40        61          75
# 6             Pravia  43.4906   -6.1508     55.00        71          40
# 7  Sao Joao Da Barra -21.6403  -41.0511     70.03        79          92
# 8            Paamiut  61.9940  -49.6678     23.45        79         100
# 9             Kodiak  57.7900 -152.4072     37.40        87          90
#
#    Wind Speed Country Current Description
# 0        8.39      RU     overcast clouds
# 1       12.53      MN     overcast clouds
# 2        1.99      AU           clear sky
# 3        4.54      CL           clear sky
# 4       10.83      TC    scattered clouds
# 5       16.11      SJ       broken clouds
# 6       12.66      ES    scattered clouds
# 7        8.55      BR     overcast clouds
# 8       28.63      GL     overcast clouds
# 9        3.44      US          light rain

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0           Barguzin      RU  53.6167  109.6167     36.75        54
# 1            Erdenet      MN  49.0333  104.0833     35.89        35
# 2          Busselton      AU -33.6500  115.3333     72.00        54
# 3               Lebu      CL -37.6167  -73.6500     54.19        85
# 4      Cockburn Town      TC  21.4612  -71.1419     73.62        63
# 5       Longyearbyen      SJ  78.2186   15.6401     10.40        61
# 6             Pravia      ES  43.4906   -6.1508     55.00        71
# 7  Sao Joao Da Barra      BR -21.6403  -41.0511     70.03        79
# 8            Paamiut      GL  61.9940  -49.6678     23.45        79
# 9             Kodiak      US  57.7900 -152.4072     37.40        87
#
#    Cloudiness  Wind Speed Current Description
# 0          93        8.39     overcast clouds
# 1         100       12.53     overcast clouds
# 2           4        1.99           clear sky
# 3           8        4.54           clear sky
# 4          28       10.83    scattered clouds
# 5          75       16.11       broken clouds
# 6          40       12.66    scattered clouds
# 7          92        8.55     overcast clouds
# 8         100       28.63     overcast clouds
# 9          90        3.44          light rain

# %%
# saving the DataFrame as a CSV file
WeatherPy_Database = city_data_df.to_csv('WeatherPy_Database.csv', index = True)
print('\nCSV String:\n', WeatherPy_Database)
# Out:
# CSV String:
#  None
